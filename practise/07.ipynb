# %%
# !pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

from imgTools import *

# %%
imageDir = "C:/Users/admin/Documents/GitHub/Computer-Vision/Images"
imageList = get_image_list(imageDir)
image = imageList[0]

# %%
plt.imshow(image)

# %%
# Draw a basic graph
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
# Draw a basic graph
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color="red")
plt.show()

# %%
# # Draw a basic graph
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color="red")  # Color
plt.title("Example about Graph")  # Title
plt.show()

# %%
# Turn off coordinate axis
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color="red")
plt.title("Example about Graph")
plt.axis("off")  # Turn off coordinate axis
plt.show()

# %%
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(image) # import image / redrawing
plt.plot(x, y, "bo--")
plt.show()
